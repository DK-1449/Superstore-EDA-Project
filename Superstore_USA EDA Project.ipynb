# %% [markdown]
# # SUPERSTORE_USA ANALYSIS(EDA)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#load the data
df = pd.read_excel("Superstore_USA.xlsx")

# %%
#explore the data using some function info,shape,head,tail,columns,describe,isnull,unique,nunique
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
# ...

# %%
df.shape
# Out:
# (9426, 24)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order Priority', 'Discount', 'Unit Price', 'Shipping Cost',
#        'Customer ID', 'Customer Name', 'Ship Mode', 'Customer Segment',
#        'Product Category', 'Product Sub-Category', 'Product Container',
#        'Product Name', 'Product Base Margin', 'Region', 'State or Province',
#        'City', 'Postal Code', 'Order Date', 'Ship Date', 'Profit',
#        'Quantity ordered new', 'Sales', 'Order ID'],
#       dtype='object')

# %%
df.head(2)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois    Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington  Anacortes        98221 2010-07-07 2010-07-08
#
#   Profit  Quantity ordered new  Sales Order ID
# 0   1.32                     2   5.90    88525
# 1   4.56                     4  13.01    88522
#
# [2 rows x 24 columns]

# %%
df.describe()
# Out:
#              Row ID     Discount   Unit Price  Shipping Cost  Customer ID  \
# count   9426.000000  9426.000000  9426.000000    9426.000000  9426.000000
# mean   20241.015277     0.049628    88.303686      12.795142  1738.422236
# min        2.000000     0.000000     0.990000       0.490000     2.000000
# 25%    19330.250000     0.020000     6.480000       3.192500   898.000000
# 50%    21686.500000     0.050000    20.990000       6.050000  1750.000000
# 75%    24042.750000     0.080000    85.990000      13.990000  2578.750000
# max    26399.000000     0.250000  6783.020000     164.730000  3403.000000
# std     6101.890965     0.031798   281.540982      17.181203   979.167197
#
#        Product Base Margin   Postal Code                     Order Date  \
# count          9354.000000   9426.000000                           9426
# mean              0.512189  52446.327286  2012-03-05 18:33:59.465308672
# min               0.350000   1001.000000            2010-01-01 00:00:00
# ...

# %%
df.nunique()
# Out:
# Row ID                  9426
# Order Priority             6
# Discount                  16
# Unit Price               751
# Shipping Cost            652
# Customer ID             2703
# Customer Name           2703
# Ship Mode                  3
# Customer Segment           4
# Product Category           3
# Product Sub-Category      17
# Product Container          7
# Product Name            1263
# Product Base Margin       51
# Region                     4
# State or Province         49
# City                    1424
# Postal Code             1697
# Order Date              1419
# Ship Date               1450
# Profit                  8984
# Quantity ordered new     112
# Sales                   8674
# Order ID                6455
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
#some data clening process
# Replace the missing value in product base margin to there mean
#df['Product Base Margin'].fillna(df['Product Base Margin'].mean(),inplace= True)

# %% [markdown]
# # showing all KPI'S by salestore regarding

# %% [markdown]
# # Total Sales

# %%
total_sales = df['Sales'].sum()
print("Total sales:",total_sales)
# Out:
# Total sales: 8951931.32

# %% [markdown]
# # Total Profit

# %%
total_profit = df['Profit'].sum().round(2)
print("Total Profit:", total_profit)
# Out:
# Total Profit: 1312442.4

# %% [markdown]
# # Total Order

# %%
total_order = df['Order ID'].count()
print("total order :",total_order)
# Out:
# total order : 9426

# %% [markdown]
# # AVG Unit Price

# %%
avg_unit_price = df['Unit Price'].mean().round()
print("Average Unit Price:", avg_unit_price)
# Out:
# Average Unit Price: 88.0

# %%
#tyep of (EDA) Exploratry data analysis 
#1) univariate analysis
#2) bivarite analysis
#3) multivariate analysis
#4) visualization analysis
#5) summary stastics
#6) outlier detection

# %% [markdown]
# # Order Priority

# %%
df['Order Priority'].unique()
# Out:
# array(['Not Specified', 'High', 'Medium', 'Low', 'Critical'], dtype=object)

# %%
df['Order Priority'] = df['Order Priority'].replace('Critical ','Critical')

# %%
df['Order Priority'].value_counts().reset_index()
# Out:
#   Order Priority  count
# 0           High   1970
# 1            Low   1926
# 2  Not Specified   1881
# 3         Medium   1844
# 4       Critical   1805

# %%
#showing which order priority has most value count
plt.figure(figsize = (6,5))
ax = sns.countplot(x = 'Order Priority', data = df,color = 'brown')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12)
plt.title('count of order priority')
plt.ylabel('count of order')
plt.show()

# %% [raw]
# # insight : the high priority category has the highest number of orders (1970),followed by low priority orders(1926)
#             as compare others priority has also good number of orders like not speficified,medium,critical

# %% [markdown]
# # year wise order analysis

# %%
df['Order Year'] = df['Order Date'].dt.year

# %%
df['Order Year'].value_counts().reset_index()
# Out:
#    Order Year  count
# 0        2013   3054
# 1        2012   2241
# 2        2011   2179
# 3        2010   1952

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x='Order Year',data = df,color='skyblue')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12)
plt.title('year wise order count')
plt.ylabel('total order count')
plt.show()

# %%
# Insights: The highest number of orders was placed in 2013 (3,054 orders), showing a significant increase compared to previous years.
#           This suggests growing demand or business expansion during this period as compare last few years

# %% [markdown]
# # Ship Mode

# %%
df['Ship Mode'].value_counts().reset_index()
# Out:
#         Ship Mode  count
# 0     Regular Air   7036
# 1  Delivery Truck   1283
# 2     Express Air   1107

# %%
x = df['Ship Mode'].value_counts().index
y = df['Ship Mode'].value_counts().values

# %%
#using pie chart for Ship mod which ship mode has most order get

# %%
plt.figure(figsize = (5,4))
plt.pie(y,labels=x,autopct ="%0.2f%%")
plt.legend(loc = 1)

# %%
# insight on Ship Mode:
# The majority of orders (7036) are shipped via Regular Air, indicating it is the most preferred and widely used shipping method.
# Delivery Truck (1283) and Express Air (1107) are significantly less common, suggesting that cost or delivery urgency may influence customers’ choices.
# This distribution highlights a potential focus on optimizing Regular Air logistics while exploring strategies to enhance the adoption of faster delivery options.

# %% [markdown]
# # Customer Segment

# %%
df['Customer Segment'].value_counts().reset_index()
# Out:
#   Customer Segment  count
# 0        Corporate   3375
# 1      Home Office   2316
# 2         Consumer   1894
# 3   Small Business   1841

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Customer Segment', data = df)
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12)
plt.title('count of Customer Segment')
plt.ylabel('count of orders')
plt.show()

# %%
# Insight on Customer Segments:
# The Corporate segment (3375 orders) represents the largest customer base, indicating strong business-related purchases. 
# The Home Office segment follows with 2316 orders, suggesting a notable demand from remote workers or small-scale operations.

# %% [markdown]
# # Product Category wise profit

# %%
# check in which product category has highest profit
df_profit=df.groupby('Product Category')['Profit'].sum().reset_index()
df_profit = df_profit.sort_values(by='Profit', ascending=False)
df_profit
# Out:
#   Product Category         Profit
# 2       Technology  683097.884748
# 1  Office Supplies  451990.216492
# 0        Furniture  177354.298188

# %%
plt.figure(figsize = (5,5))
ax = sns.barplot(x = 'Product Category',y = 'Profit',data = df,estimator = 'sum')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12)
plt.title('product category wise profit')
plt.ylabel('total profit')
plt.show()

# %%
#Insight on Product Category Profitability:
#The Technology category generates the highest profit ($683K), indicating strong demand and higher profit margins. 
#Office Supplies follows with $452K, showing steady profitability, possibly due to frequent bulk purchases.

# %% [markdown]
# # which product category has most shiping mode use

# %%
ship_mode_counts = df.groupby(['Ship Mode','Product Category']).size().reset_index(name='Count').sort_values(by='Ship Mode', ascending=False)
ship_mode_counts
most_used_ship_mode = ship_mode_counts.loc[ship_mode_counts.groupby('Product Category')['Count'].idxmax()].sort_values(by='Ship Mode', ascending=False)
most_used_ship_mode
# Out:
#         Ship Mode Product Category  Count
# 7     Regular Air  Office Supplies   4426
# 8     Regular Air       Technology   1772
# 0  Delivery Truck        Furniture    956

# %%
plt.figure(figsize = (6,6))
ax = sns.countplot(x = 'Ship Mode' , data = df, hue = 'Product Category')
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}',
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12)
plt.title('shiping mode wise product category count')
plt.ylabel('count of category')
plt.show()

# %%
# Insight on Shipping Mode and Product Category:
# The Regular Air shipping mode is most commonly used for Office Supplies (4426 counts), followed by Technology (1772 counts), 
# indicating that Office Supplies have a higher demand for air shipping. On the other hand, Furniture relies more on Delivery Truck 
# for shipping (956 counts), possibly due to larger sizes or weight requiring ground transportation.

# %% [markdown]
# # which product category has most order

# %%
df['Product Category'].value_counts().reset_index()
# Out:
#   Product Category  count
# 0  Office Supplies   5181
# 1       Technology   2312
# 2        Furniture   1933

# %%
plt.figure(figsize = (5,5))
ax = sns.countplot(x = 'Product Category', data = df,color = 'orange')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                ha='center', va='bottom')
plt.title('count of product category')
plt.ylabel('count of orders')
plt.show()

# %%
# Insight on Product Category Distribution:
# The Office Supplies category has the highest count (5181), indicating that it is the most purchased product category. 
# Technology follows with 2312, showing a solid demand but at a lower rate than Office Supplies. 
# Furniture has the least count (1933), which could suggest either lower sales volume or higher price points, 
# making it less frequently purchased compared to the other categories.

# %% [markdown]
# # product category with there sub-category wise analysis

# %% [markdown]
# # office supplies with there sub-category

# %%
office_supplies_df = df[df['Product Category'] == 'Office Supplies'].reset_index()
pd.DataFrame(office_supplies_df[['Product Category','Product Sub-Category']].count())
# Out:
#                          0
# Product Category      5181
# Product Sub-Category  5181

# %%
plt.figure(figsize = (10,8))
ax = sns.countplot(x = 'Product Category', data= df [df['Product Category']=='Office Supplies'],hue = 'Product Sub-Category')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                ha='center', va='bottom')
plt.title('office supplies category with there sub-category wise analysis')
plt.ylabel('count of orders')
plt.show()

# %% [markdown]
# # Technology wise sub-category analysis

# %%
Technology_df = df[df['Product Category'] == 'Technology'].reset_index()
pd.DataFrame(Technology_df[['Product Category','Product Sub-Category']].count())
# Out:
#                          0
# Product Category      2312
# Product Sub-Category  2312

# %%
plt.figure(figsize = (6,5))
ax = sns.countplot(x = 'Product Category', data= df [df['Product Category']=='Technology'],hue = 'Product Sub-Category')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                ha='center', va='bottom')
plt.title('Technology category with there sub-category wise analysis')
plt.ylabel('count of orders')
plt.legend(loc='upper right',fontsize = 6)
plt.show()

# %% [markdown]
# # Furniture wise sub-category analysis

# %%
Furniture_df = df[df['Product Category'] == 'Furniture'].reset_index()
pd.DataFrame(Furniture_df[['Product Category','Product Sub-Category']].count())
# Out:
#                          0
# Product Category      1933
# Product Sub-Category  1933

# %%
plt.figure(figsize = (6,5))
ax = sns.countplot(x = 'Product Category', data= df [df['Product Category']=='Furniture'],hue = 'Product Sub-Category')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                ha='center', va='bottom')
plt.title('Furniture category with there sub-category wise analysis')
plt.ylabel('total orders count')
plt.show()

# %% [markdown]
# # State wise analysis

# %% [markdown]
# # Top 10 state with most order

# %%
df['State or Province'].value_counts().reset_index().head(10)
# Out:
#   State or Province  count
# 0        California   1021
# 1             Texas    646
# 2          Illinois    584
# 3          New York    574
# 4           Florida    522
# 5              Ohio    396
# 6        Washington    327
# 7          Michigan    327
# 8      Pennsylvania    271
# 9    North Carolina    251

# %%
# plot the top 10 high sales state
plt.figure(figsize=(14,7))
ax = sns.countplot(x='State or Province',data=df,order=df['State or Province'].value_counts().head(10).index, hue='State or Province')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() / 2, i.get_height()), 
                ha='center', va='bottom')
plt.title("Top 10 high orders state")
plt.ylabel('count of orders')
plt.show()

# %% [markdown]
# # city wise analysis

# %% [markdown]
# # Top 5 cities with most orders

# %%
df['City'].value_counts().reset_index().head(5)
# Out:
#             City  count
# 0  New York City    202
# 1    Los Angeles    196
# 2        Seattle     93
# 3        Chicago     90
# 4         Boston     80

# %% [markdown]
# # Region wise analysis

# %%
sales_by_region.reset_index()
# Out:
#     Region  count
# 0  Central   2899
# 1     East   2289
# 2     West   2284
# 3    South   1954

# %%
sales_by_region = df['Region'].value_counts()
plt.figure(figsize=(8, 5))
ax = sns.barplot(x=sales_by_region.index, y=sales_by_region.values,hue=sales_by_region.index,palette='coolwarm')
for i in ax.patches:
    ax.annotate(f'{int(i.get_height())}',
                (i.get_x() + i.get_width() /4, i.get_height()), 
                ha='center', va='bottom')
plt.title('Total orders by Region')
plt.xlabel('Region')
plt.ylabel('Total orders')
plt.show()

# %% [markdown]
# # Year wise sales trend

# %%
sales_over_time = df.groupby('Order Year')['Sales'].sum().reset_index()
sales_over_time['Order Year'] = sales_over_time['Order Year']
df['Order Year'] = pd.to_datetime(df['Order Year'], format='%Y')

# %%
sales_over_time
# Out:
#   Order Year       Sales
# 0 2010-01-01  1924332.88
# 1 2011-01-01  1944507.43
# 2 2012-01-01  2230731.18
# 3 2013-01-01  2852359.83

# %%
plt.figure(figsize=(10,6))
sns.lineplot(x='Order Year', y='Sales', data=sales_over_time, marker="o", color='blue')
plt.title('Sales Over Time (By Year)')
plt.xlabel('Year')
plt.ylabel('Total Sales ($)')
plt.grid(True)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # What are the total sales and profit by product name?

# %%
product_sales_profit = df.groupby('Product Name')[['Sales', 'Profit']].sum().reset_index()
product_sales_profit = product_sales_profit.sort_values(by='Sales', ascending=False)
product_sales_profit
# Out:
#                                           Product Name      Sales       Profit
# 565     Global Troy™ Executive Leather Low-Back Tilter  194025.64  79509.39220
# 895  Riverside Palais Royal Lawyers Bookcase, Royal...  190195.15   7681.81624
# 325              Canon imageCLASS 2200 Advanced Copier  107697.73  -5665.44046
# 322                      Canon PC1080F Personal Copier  102932.77  20916.46094
# 591  Hewlett-Packard cp1700 [D, PS] Series Color In...  102889.95  33721.10020
# ..                                                 ...        ...          ...
# 955                  Sony IBM Color Diskettes, 25/Pack      18.17   -355.77552
# 178                                          Avery 482      16.67     -2.00970
# 278                               Blackstonian Pencils      13.18     -0.65720
# 9                           *Staples* Packaging Labels      11.71     44.36760
# 154                              Alliance Rubber Bands       7.43     -3.01320
#
# [1263 rows x 3 columns]

# %%
# Top 10 products by sales
top_products = product_sales_profit.head(10)
plt.figure(figsize=(12,6))
sns.barplot(x='Sales', y='Product Name', data=top_products, hue= 'Product Name',palette='magma')
plt.title('Top 10 Products by Sales')
plt.xlabel('Total Sales ($)')
plt.ylabel('Product Name')
plt.show()

# %%
# Top 10 Customers by Sales or Profit

# %%
top_customers = df.groupby('Customer Name')[['Sales','Profit']].sum().sort_values(by = 'Sales',ascending=False).head(10)
top_customers
# Out:
#                            Sales        Profit
# Customer Name
# Gordon Brandt          123745.62   7228.904000
# Glen Caldwell           89269.70   6469.930727
# Rosemary O'Brien        86540.75   7272.486500
# Leigh Burnette Hurley   83651.70   9289.944500
# Kristine Connolly       81296.39   4195.597000
# Nina Horne Kelly        78243.60  16432.454100
# Neal Wolfe              69118.00   5529.446000
# Priscilla Kane          61610.60   5504.259200
# Dana Teague             61298.98   4556.533700
# Kim Weiss               58947.41   -410.296692

# %%
plt.figure(figsize=(5,5))
sns.barplot(x='Sales', y='Customer Name', data=top_customers, hue= 'Customer Name',palette='coolwarm')
plt.title('Top 10 Customer by Sales')
plt.xlabel('Total Sales ($)')
plt.ylabel('Customer Name')
plt.show()
